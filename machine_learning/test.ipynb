# %%
from ultralytics import YOLO

model = YOLO('yolo26n.pt') 

results = model('giraffe.jpg')

results[0].show()

results[0].save(filename='giraff_output.jpg')
# Out:
# image 1/1 /home/aleczo/Documents/Repositories/tYOLO/bus.jpg: 448x640 1 bus, 51.1ms
# Speed: 2.7ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
# 'wynik_detekcji.jpg'
# /usr/bin/eog: symbol lookup error: /snap/core20/current/lib/x86_64-linux-gnu/libpthread.so.0: undefined symbol: __libc_pthread_init, version GLIBC_PRIVATE
